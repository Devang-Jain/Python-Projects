# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\Devang Jain\Downloads\Weather Data.csv')

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.shape
# Out:
# (8784, 8)

# %%
df['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df[df['Weather']=='Clear'].shape
# Out:
# (1326, 8)

# %%
df[df['Wind Speed_km/h']>=5]
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# 5    2012-01-01 05:00:00    -1.4              -3.3         87
# 6    2012-01-01 06:00:00    -1.5              -3.1         89
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather  Month
# 2                   7            4.0     101.26  Freezing Drizzle,Fog      1
# ...

# %%
df.Weather.value_counts().to_frame().reset_index()
# Out:
#                                       index  Weather
# 0                              Mainly Clear     2106
# 1                             Mostly Cloudy     2069
# 2                                    Cloudy     1728
# 3                                     Clear     1326
# 4                                      Snow      390
# 5                                      Rain      306
# 6                              Rain Showers      188
# 7                                       Fog      150
# 8                                  Rain,Fog      116
# 9                               Drizzle,Fog       80
# 10                             Snow Showers       60
# 11                                  Drizzle       41
# 12                                 Snow,Fog       37
# 13                        Snow,Blowing Snow       19
# 14                                Rain,Snow       18
# 15               Thunderstorms,Rain Showers       16
# 16                                     Haze       16
# ...

# %% [markdown]
# ### 1. Statistics

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# ### 2. Data Cleaning (Data and Time )

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])
import datetime as dt
df['Month'] = df['Date/Time'].dt.month
df
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather  Month  \
# 0                   4            8.0     101.24                   Fog      1
# ...

# %% [markdown]
# ### 3. Temperature and Dew Point Over Time

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date/Time'], df['Temp_C'], label='Temperature (°C)')
plt.plot(df['Date/Time'], df['Dew Point Temp_C'], label='Dew Point (°C)')
plt.title('Temperature and Dew Point Over Time')
plt.xlabel('Date/Time')
plt.ylabel('Temperature (°C)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Distribution of wind speed

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Wind Speed_km/h'], bins=20, edgecolor='black')
plt.title('Distribution of Wind Speed')
plt.xlabel('Wind Speed (km/h)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 5. Display a scatter plot of temperature vs. pressure

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Temp_C'], df['Press_kPa'], alpha=0.5)
plt.title('Temperature vs. Pressure')
plt.xlabel('Temperature (°C)')
plt.ylabel('Pressure (kPa)')
plt.show()

# %% [markdown]
# ### 6. Visualize the distribution of humidity

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Rel Hum_%'], bins=20, edgecolor='black')
plt.title('Distribution of Relative Humidity')
plt.xlabel('Relative Humidity (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 7. Visualize wind speed distribution

# %%
plt.figure(figsize=(8, 6))
plt.hist(df['Wind Speed_km/h'], bins=20, edgecolor='black')
plt.title('Distribution of Wind Speed')
plt.xlabel('Wind Speed (km/h)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 8. The top 10 relationships between wind speed and weather conditions

# %%
# Get the top 10 most frequent weather conditions
top_weather_conditions = df['Weather'].value_counts().nlargest(10).index
df_top_conditions = df[df['Weather'].isin(top_weather_conditions)]
 
# Calculate the average wind speed for each weather condition
average_wind_speed = df_top_conditions.groupby('Weather')['Wind Speed_km/h'].mean().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=average_wind_speed.values, y=average_wind_speed.index, palette='viridis')
plt.title('Top 10 Relationships Between Wind Speed and Weather Conditions')
plt.xlabel('Average Wind Speed (km/h)')
plt.ylabel('Weather Condition')
plt.show()

# %% [markdown]
# ### 9. Correlation Analysis

# %%
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### 10. Weather Condition Distribution:

# %%
plt.figure(figsize=(20,16))
weather_counts = df['Weather'].value_counts()
weather_counts.plot(kind='bar', color='skyblue', width=0.8)  # Adjust the width for better visualization
plt.xlabel('Weather Condition')
plt.ylabel('Frequency')
plt.title('Weather Condition Distribution')
plt.xticks(rotation=90)

# Define bins in intervals of 50
plt.yticks(range(0, max(weather_counts) + 1, 50))

plt.show()

# %% [markdown]
# ### 11. Daily Temperature Patterns

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x=df['Date/Time'].dt.hour, y=df['Temp_C'], ci=None)
plt.xlabel('Hour of the Day')
plt.ylabel('Temperature (°C)')
plt.title('Daily Temperature Patterns')
plt.show()

# %% [markdown]
# ### 12. Dew point vs Temperature

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['Temp_C'], y=df['Dew Point Temp_C'])
plt.xlabel('Temperature (°C)')
plt.ylabel('Dew Point Temperature (°C)')
plt.title('Dew Point vs. Temperature')
plt.show()

# %% [markdown]
# ### 13. Temperature over time

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['Date/Time'], df['Temp_C'], color='green', alpha=0.7, label='Temperature (°C)')
plt.xlabel('Date/Time')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Over Time (Bar Chart)')
plt.legend()
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### 14. Temperature Trends Month-wise

# %%
# Convert 'Date/Time' column to datetime format
df['Date/Time'] = pd.to_datetime(df['Date/Time'])
 
# Extract month from 'Date/Time'
df['Month'] = df['Date/Time'].dt.month_name()
plt.figure(figsize=(12, 6))
sns.lineplot(x='Month', y='Temp_C', data=df, ci=None)
plt.fill_between(x='Month', y1='Temp_C', data=df, alpha=0.2)  # Fill area under the line
plt.title('Temperature Trends Month-wise (Area Chart)')
plt.xlabel('Month')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## THANK YOU
